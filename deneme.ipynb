# %%
import numpy as np

# Voxel verisi (örnek olarak 100x100x100 yoğunluk matrisi)
volume = np.random.rand(100, 100, 100)  # VOXEL VERİ

# Volumetrik görselleştirme (örnek)
from vedo import Volume, show
v = Volume(volume)
show(v, axes=1, title="Volumetric Rendering of X-Ray Data")
# Out:
# <PIL.Image.Image image mode=RGB size=800x600>
